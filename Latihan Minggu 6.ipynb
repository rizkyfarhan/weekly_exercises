# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## PERTAMA

# %%
data = pd.read_csv('tabelgabungan.csv')

# %%
data.head()
# Out:
#      nama fakultas       prodi matakuliah  nilai
# 0   Agung   teknik       sipil   Kalkulus     90
# 1  Brahma   teknik  arsitektur   Olahraga     60
# 2   Citra  ekonomi   manajemen     Fisika     70
# 3    Deni    hukum  ilmu hukum  Statistik     80
# 4  Stella    fisip       adpub  Manajemen     80

# %%
data.describe().transpose()
# Out:
#        count  mean        std   min   25%   50%   75%    max
# nilai   10.0  71.0  20.248457  30.0  62.5  75.0  80.0  100.0

# %%
sns.countplot(data['fakultas'])

# %%
sns.countplot(data['prodi'])

# %%
sns.distplot(data['nilai'])

# %%
sns.boxplot(data['nilai'])

# %%
sns.swarmplot(x='fakultas',y='nilai',data=data)

# %% [markdown]
# ## KEDUA

# %%
emp = pd.read_csv('employee_visualisasi.csv')

# %%
emp.head()
# Out:
#    emp_no first_name  last_name gender   hire_date   from_date     to_date  \
# 0   10017  Cristinel  Bouloucos      F  1993-08-03  1993-08-03  1994-08-03
# 1   10017  Cristinel  Bouloucos      F  1993-08-03  1994-08-03  1995-08-03
# 2   10017  Cristinel  Bouloucos      F  1993-08-03  1995-08-03  1996-08-02
# 3   10017  Cristinel  Bouloucos      F  1993-08-03  1996-08-02  1997-08-02
# 4   10017  Cristinel  Bouloucos      F  1993-08-03  1997-08-02  1998-08-02
#
#    salary         title dept_no
# 0   71380  Senior Staff    d001
# 1   75538  Senior Staff    d001
# 2   79510  Senior Staff    d001
# 3   82163  Senior Staff    d001
# 4   86157  Senior Staff    d001

# %%
emp.describe()
# Out:
#              emp_no         salary
# count   1000.000000    1000.000000
# mean   10704.214000   73675.089000
# std      316.063409   17438.945788
# min    10017.000000   39563.000000
# 25%    10449.000000   60429.000000
# 50%    10778.000000   72756.500000
# 75%    10938.000000   85872.000000
# max    11190.000000  126034.000000

# %%
sns.countplot(emp['gender'])

# %%
plt.figure(figsize=(20,5))
sns.stripplot(x='first_name',y='salary',data=emp)

# %%
sns.stripplot(x='title',y='salary',data=emp)

# %%
sns.stripplot(x='gender',y='salary',data=emp)

# %%
sns.boxplot(x='gender',y='salary',data=emp)

# %%
sns.boxplot(x='title',y='salary',data=emp)

# %% [markdown]
# ## KETIGA

# %%
data3 = pd.read_excel('Latohan.xlsx')

# %%
data3.head()
# Out:
#    Transaction Purchase Date  Customer ID Gender Marital Status Homeowner  \
# 0            1    2011-12-18         7223      F              M         Y
# 1            2    2011-12-20         7841      M              M         Y
# 2            3    2011-12-21         8374      F              M         N
# 3            4    2011-12-21         9619      M              M         Y
# 4            5    2011-12-22         1900      F              S         Y
#
#    Children           City State or Province Country Product Family  \
# 0         2    Los Angeles                CA     USA           Food
# 1         5    Los Angeles                CA     USA           Food
# 2         2      Bremerton                WA     USA           Food
# 3         3       Portland                OR     USA           Food
# 4         3  Beverly Hills                CA     USA          Drink
#
#   Product Department      Product Category  Units Sold  Revenue  Annual Income
# ...

# %%
sns.countplot(data3['Gender'])

# %%
sns.barplot(x='Gender',y='Annual Income',data=data3)

# %%
sns.countplot(data3['Marital Status'])

# %%
sns.countplot(data3['Homeowner'])

# %%
sns.countplot(data3['Children'])

# %%
sns.countplot(data3['Product Family'])

# %%
plt.figure(figsize=(25,5))
sns.countplot(data3['Product Department'])

# %%
plt.figure(figsize=(40,5))
sns.countplot(data3['Product Category'])

# %%
bypcat = data3.groupby('Product Category')
bypcat['Units Sold'].sum().sort_values(ascending=False)
# Out:
# Product Category
# Vegetables              7023
# Snack Foods             6487
# Dairy                   3732
# Fruit                   3195
# Meat                    3114
# Jams and Jellies        2384
# Baking Goods            1945
# Bread                   1749
# Breakfast Foods         1687
# Canned Soup             1620
# Bathroom Products       1498
# Beer and Wine           1460
# Candy                   1448
# Paper Products          1411
# Electrical              1406
# Frozen Desserts         1306
# Specialty               1202
# Starchy Foods           1163
# Hot Beverages            908
# Kitchen Products         865
# Magazines                815
# Hygiene                  813
# Eggs                     808
# Pizza                    798
# Pain Relievers           789
# Cleaning Supplies        788
# Pure Juice Beverages     655
# Carbonated Beverages     634
# Side Dishes              631
# Drinks                   564
# Plastic Products         549
# ...

# %%
sns.heatmap(data3.corr(),annot=True)

# %%
sns.boxplot(data3['Annual Income'],orient='v')

# %%
sns.distplot(data3['Revenue'])

# %%
sns.boxplot(x='Country',y='Annual Income',data=data3)

# %%
sns.boxplot(x='Product Family',y='Revenue',data=data3)

# %%
sns.boxplot(x='Country',y='Children',data=data3)

# %%
sns.boxplot(x='Marital Status',y='Annual Income',data=data3)
